# %% [markdown]
# # static

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %matplotlib inline

# %%
DATA_PATH = f"{os.getcwd()}{os.sep}names{os.sep}" # поставил os.sep, потому что работал над кодом на маке и под виндой
DATA_PATH
# Out:
# '/Users/britishpop/Documents/python_studies/netology_python/4.2_visualisation/names/'

# %% [markdown]
# # names 1900-2000

# %%
def centennial_names():
    names_by_year = {}
    for year in range(1900,2001):
        names_by_year[year] = pd.read_csv(DATA_PATH + f"yob{year}.txt", names = ["Name", "Gender", "Count"])
    name_all = pd.concat(names_by_year, names = ["Year", "Pos"])
    name_dynamics = name_all.groupby([name_all.index.get_level_values(0), "Name"]).sum()
    graph = name_dynamics.query("Name == ['Ruth', 'Robert']").unstack("Name").plot()
    return graph

res = centennial_names()
print(res)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# # names 1900-2000, 5 year gaps, histogram

# %%
def centennial_names():
    names_by_year = {}
    for year in range(1900,2001,5):
        names_by_year[year] = pd.read_csv(DATA_PATH + f"yob{year}.txt", names = ["Name", "Gender", "Count"])
    name_all = pd.concat(names_by_year, names = ["Year", "Pos"])
    name_dynamics = name_all.groupby([name_all.index.get_level_values(0), "Name"]).sum()
    graph = name_dynamics.query("Name == ['Ruth', 'Robert']").unstack("Name").plot.bar()
    return graph

res = centennial_names()
print(res)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# # top10 starting with "R" in 1950

# %%
def top_1950():
    names_1950 = {}
    names_1950 = pd.read_csv(DATA_PATH + "yob1950.txt", names = ["Name", "Gender", "Count"])
    r_names = names_1950.Name.str.startswith("R")
    r_names_top = names_1950[r_names].sort_values(by="Count", ascending=False).head(10).set_index("Name")
    r_names_top.plot.pie(y="Count") 
    return r_names_top

res = top_1950()
print(res)
# Out:
#         Gender  Count
# Name
# Robert       M  83565
# Richard      M  51001
# Ronald       M  29916
# Roger        M  12548
# Raymond      M  11179
# Rebecca      F   9427
# Ruth         F   7128
# Roy          M   6456
# Rita         F   6424
# Ralph        M   6404

# %% [markdown]
# # consonants dots

# %%
def count_consonants(string):
    return sum(1 for char in string.lower() if char in "bcdfghjklmnpqrstvwxz")


def consonant_names():
    names_by_year = {}
    for year in range(1900,2001):
        names_by_year[year] = pd.read_csv(DATA_PATH + f"yob{year}.txt", names = ["Name", "Gender", "Count"])
    name_all = pd.concat(names_by_year, names = ["Year", "Pos"])
    consonants = name_all.groupby('Name').sum().reset_index()
    consonants['Count_consonants'] = consonants.Name.apply(count_consonants)
    consonants.plot.scatter(x='Count_consonants', y='Count')
    
    
consonant_names()
